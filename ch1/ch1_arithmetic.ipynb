# %%
##EXERCISE


round(42.5) ## round down to get even 42
round(55.5) ##round up to get even 56
round(79.5)  ##round up to get even 80

##EXERCISE

-2 ## -2

+2 ## 2

2++2 ## 4

"""
4 2 ##SyntaxError: invalid syntax

round(33.5 ##SyntaxError: invalid syntax
      
round 33.5 ##SyntaxError: invalid syntax
"""

##EXERCISE

type(765) #int

type(2.718) #float

type('2 pi') #str

abs(-7) #7

abs(-7.0) #7.0

type(abs(-7)) #int

type(abs(-7.0)) #float

type(abs) #builtin_function_or_method

type(int) #type

type(type) #type


##EXERCISE

import pprint
total_seconds = 42*60 + 42
pprint.pprint(f"Total Seconds :  {total_seconds}") #'Total Seconds :  2562'

## 1.61 km = 1 mile
number_of_miles = 10 / 1.61
pprint.pprint(f"Number of Miles : {number_of_miles : .2f}") #'Number of Miles :  6.21'

## 10 km = 10/1.61 mile
seconds_per_mile = total_seconds / number_of_miles
pprint.pprint(f"Seconds per mile : {seconds_per_mile}") #'Seconds per mile : 412.482'

average_pace_in_minutes = int(seconds_per_mile // 60) ## // floor division

average_pace_in_seconds = seconds_per_mile % 60 ## % remainder

pprint.pprint(f"average pace in {average_pace_in_minutes} minutes and {average_pace_in_seconds : .3f} seconds") #'average pace in 6 minutes and  52.482 seconds'

## approach 1
hours = total_seconds / 3600

miles_per_hour = number_of_miles / hours

pprint.pprint(f"Miles per hour : {miles_per_hour : .3f}") ## 'Miles per hour :  8.728'

## approach 2
pprint.pprint(f"Miles per hour : {(60 * 60) / seconds_per_mile : .3f}") ## 'Miles per hour :  8.728'
# Out:
# 'Total Seconds :  2562'
# 'Number of Miles :  6.21'
# 'Seconds per mile : 412.482'
# 'average pace in 6 minutes and  52.482 seconds'
# 'Miles per hour :  8.728'
# 'Miles per hour :  8.728'
